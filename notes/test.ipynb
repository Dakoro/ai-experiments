# %%
import numpy as numpy

result = []

for x1 in range(1, 7):
    for x2 in range(1, 7):
        result.append(x1*x2)

# %%
len([n for n in result if n >= 20]) / len(result)
# Out:
# 0.2222222222222222
