# %%
import torch

# %%
total_flops = 6 * 70e9 * 15e12
h100_flops_per_sec = 1979e12 / 2
mfu = 0.5
flops_per_days = h100_flops_per_sec * mfu * 1024 * 3600 * 24
days = total_flops / flops_per_days
days
# Out:
# 143.92659381842682

# %%
num_gpus = torch.cuda.device_count()
for i in range(num_gpus):
    print(torch.cuda.get_device_capability(i))
torch.cuda.memory_reserved()
# Out:
# (8, 9)
# 0
